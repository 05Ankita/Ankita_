# %% [raw]
# 1.What are the two values of the Boolean data type? How do you write them?
# Ans:The two types of boolean data type are True and False.We can Write them like this True,False.
#
# 2.What are the three different types of Boolean operators?
# The three different types of boolean operators are AND,OR,NOT.
#
# 3.Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
# Ans:
#  AND table    OR Table   NOT Table
#  T F F        T F T      T F
#  F T F        F T T      F T
#  T T T        T T T
#  F F F        F F F
#
# 4.What are the values of the following expressions?
# (5 > 4) and (3 == 5)               Ans:  F
# not (5 > 4)                              F
# (5 > 4) or (3 == 5)                      T
# not ((5 > 4) or (3 == 5))                F
# (True and True) and (True == False)      F
# (not False) or (not True)                T
#
# 5. What are the six comparison operators?
# Ans: The six comparison operators are greater than(>),Lesser than(<),Greater than equals to(>=),less tha equals to(<=),equals to(==),not eqauls to(!=).
#
# 6.How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
# Ans: We use equal to when we compare two values to check whether they are equal or not and we use assignment operators when we assign any value to any variable.
# I want to check whether a and b are equal or not,there i use equal to operator.
# ex:a=10(assignment operator)
#    b=10
#    if(a==b): //equals to check whether they are same or not
#       print("Hello World")
#     else:
#       print("bye")
#
# 7.Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print('eggs')
# if spam > 5:
# print('bacon')
# else:
# print('ham')
# print('spam')
# print('spam')
#
# Ans:spam = 0
# if spam == 10:
# print('eggs')
#  first block
# if spam > 5:
# print('bacon')
#  second block
# else:
# print('ham')
# print('spam')
# print('spam')
#  third block
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
# Ans:
# try:
#     spam=int(input())
#     if spam==1:
#         print("Hello")
#     elif spam==2:
#         print("Howdy")
#     else:
#         print("Greetings")
# except:
#     print("please Enter integer")
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
# Ans: Ctrl+C
#
# 10.How can you tell the difference between break and continue?
# Ans:Break statement terminates the whole iteration loop and comes out of the loop and continue skips the single iteration in a loop.
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# Ans:In three cases the output will be same.In range(10) by default it will print from 0 to 9 with step difference of 1.In range(0,10) it will print from 0 to 9 with step difference of 1.In range(0,10,1) it will print from 0 to 9 with step difference of 1.
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
#
# Ans:for i in range(0,10):
#     print(i)
#
#     i=0
# while(i<10):
#     print(i)
#     i=i+1
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
# Ans:spam.bacon(argument)
